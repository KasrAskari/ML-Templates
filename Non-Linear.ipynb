# %% [markdown]
# ### 1- Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2- Loading Dataset

# %%
# df = pd.read_csv("filename")
# df.head(10)
# df.tail(10)

# %% [markdown]
# ### 3- EDA (Exploratory Data Analysis)

# %%
# df.describe()

# %% [markdown]
# ### 4- Plotting the Dataset

# %%
# plt.figure(figsize=(8,5))
# x_data, y_data = (df["1"].values, df["2"].values)

# plt.plot(x_data, y_data, 'go')
# plt.ylabel('1')
# plt.xlabel('2')
# plt.show()

# %% [markdown]
# #### Choosing Model

# %% [markdown]
# ##### Linear

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 2*(x) + 3
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
#plt.figure(figsize=(8,6))
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ##### Cubic

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ##### Quadratic

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ##### Exponential

# %%
X = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

Y= np.exp(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ##### Logarithmic

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3868\2233958358.py:3: RuntimeWarning: invalid value encountered in log
#   Y = np.log(X)

# %% [markdown]
# ##### Sigmoidal/Logistic

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1.0 / (1.0 + np.exp(-X))

plt.plot(X,Y)
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ### 5- Build The Model

# %% [markdown]
# #### Cubic

# %%
def cubic(x, a, b, c, d):
    y = a * x**3 + b * x**2 + c * x + d
    return y

# %% [markdown]
# #### Qaudratic

# %%
def quadratic(x, a, b, c):
    y = a * x**2 + b * x + c
    return y

# %% [markdown]
# #### Exponential

# %%
def exponential(x, a, b):
    y = a * np.exp(b * x)
    return y

# %% [markdown]
# #### Sigmoidal/Logistic

# %%
def sigmoid(x, beta_1, beta_2):
    y = 1 / (1 + np.exp(-beta_1*(x-beta_2)))
    return y

# %% [markdown]
# #### Trying to Fit our Model

# %%
# beta_1 = 0.80
# beta_2 = 2010.0

# # Logistic Function
# Y_pred = sigmoid(x_data, beta_1, beta_2)

# # Plot Initial Prediction
# plt.plot(x_data, Y_pred * 20000000000000.)
# plt.plot(x_data, y_data, 'ro')

# %% [markdown]
# ### 6- Normalization

# %%
# xdata = x_data/max(x_data)
# ydata = y_data/max(y_data)

# print("----- xdata -----")
# print(xdata)
# print("----- ydata -----")
# print(ydata)

# %% [markdown]
# ### 7- Find The Best Parameters (optimization)

# %% [markdown]
# #### Logistic

# %%
# from scipy.optimize import curve_fit
# popt, pcov = curve_fit(sigmoid, xdata, ydata)

# print("beta_1 = %f, beta_2 = %f" % (popt[0], popt[1]))

# %% [markdown]
# ### 8- Our Result Model

# %%
# x = np.linspace(1960, 2014, 50)
# x = x/max(x)
# plt.figure(figsize=(8,5))

# y = sigmoid(x, *popt)
# plt.plot(xdata, ydata, 'ro', label='data')
# plt.plot(x, y, linewidth=3.0, label='fit')

# plt.legend(loc='best')
# plt.ylabel('1')
# plt.xlabel('2')
# plt.show()

# %% [markdown]
# ### 9- Checking The Accuracy

# %%
# from sklearn.metrics import mean_squared_error, r2_score

# mse = mean_squared_error(ydata, Y_pred)
# r2 = r2_score(ydata, Y_pred)

# print(f'Mean Squared Error: {mse:.2f}')
# print(f'R2-Score: {r2:.2f}')
